# %%
import os
import glob
import pandas as pd
from dynasaur.plugins.data_visualization_controller import DataVisualizationController
from dynasaur.plugins.criteria_controller import CriteriaController
import csv


def main():

    cwd = os.path.normpath(os.getcwd() + os.sep + os.pardir)
    input_dir_auxiliaries = os.path.join(cwd, "Data/results_and_file_definition")
    input_dir_sim = os.path.join(cwd, "Data/results_and_file_definition")
    output_dir = os.path.join(cwd, "Data/results")

    path_to_def = os.path.join(input_dir_auxiliaries, "dataviz_criteria.def")
    path_to_def_id = os.path.join(input_dir_auxiliaries, "history_node_id.def")
    path_to_data = os.path.join(input_dir_sim, "binout*")

    data_vis_controller = DataVisualizationController(calculation_procedure_def_file=path_to_def,
                                                      object_def_file=path_to_def_id,
                                                      data_source=path_to_data)

    commands = [
        {'visualization': 'NECK_node_xvel', 'x_label': 'time[ms]', 'y_label': 'x_vel'}]

    for command in commands:
        data_vis_controller.calculate(command)

    data_vis_controller.write_CSV(output_dir, filename="diagram.csv")
    dataFrame = pd.read_csv(os.path.join(output_dir, "diagram.csv"), delimiter=';', header=[0,1,2,3])
    
    #crit_controller = CriteriaController(calculation_procedure_def_file=path_to_def, object_def_file=path_to_def_id,
                                    #     data_source=path_to_data)

    #commands = [{'criteria': 'BOARD_solid_obj_1_stress'},
            #    {'criteria': 'BOARD_solid_obj_2_stress'},
             #   {'criteria': 'MODEL_Internal_Energy_Max'}]

    #for command in commands:
        #crit_controller.calculate(command)

    #crit_controller.write_CSV(output_dir, filename="criteria.csv")



if __name__ == "__main__":
    main()
# Out:
# [READ DYNASAUR DEF]	read c:\Users\d069056\OneDrive - Politecnico di Torino\File di Alessandro  Scattina - S361385_TOMASSI_Stefano\Conferences\IRCOBI_2026\HIVE - Holistic Injury Visualization Environment\Data/results_and_file_definition\dataviz_criteria.def
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [WARNING]	Double declaration of NECK_node_xvel
# [READ DYNASAUR DEF]	done
# [READ DYNASAUR DEF]	read c:\Users\d069056\OneDrive - Politecnico di Torino\File di Alessandro  Scattina - S361385_TOMASSI_Stefano\Conferences\IRCOBI_2026\HIVE - Holistic Injury Visualization Environment\Data/results_and_file_definition\history_node_id.def
# [READ DYNASAUR DEF]	done
# [READ BINOUT]	read nodout data ...
# [READ BINOUT]	done reading nodout!
# [CALCULATION]	Calculating Visualization: NECK_node_xvel
# [DATA]	read id 1999998 from channel name: x_velocity
# [CALCULATION]	DATA VISUALIZATION writing csv to c:\Users\d069056\OneDrive - Politecnico di Torino\File di Alessandro  Scattina - S361385_TOMASSI_Stefano\Conferences\IRCOBI_2026\HIVE - Holistic Injury Visualization Environment\Data/results
# [CALCULATION]	DATA VISUALIZATION done writing csv to c:\Users\d069056\OneDrive - Politecnico di Torino\File di Alessandro  Scattina - S361385_TOMASSI_Stefano\Conferences\IRCOBI_2026\HIVE - Holistic Injury Visualization Environment\Data/results\diagram.csv
